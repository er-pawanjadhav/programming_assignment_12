# %%
#Write a Python program to sort Python Dictionaries by Key or Value?
d= {"b":2,'c':3,'a':5,"d":10,'f':7,'e':9}
d1={}
for i in sorted(d):
    d1[i] = d[i]
print(d1)
# Out:
# {'a': 5, 'b': 2, 'c': 3, 'd': 10, 'e': 9, 'f': 7}
