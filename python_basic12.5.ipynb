# %%
from collections import OrderedDict as od
  

id1 =od([('a', '1'), ('b', '2')])
  

id1.update({'c':'3'})
id1.move_to_end('c', last = False)
  

print (id1)
# Out:
# OrderedDict([('c', '3'), ('a', '1'), ('b', '2')])
